# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11017412629","type":"PullRequestEvent","actor":{"id":104161,"login":"mirisuzanne","display_login":"mirisuzanne","gravatar_id":"","url":"https://api.github.com/users/mirisuzanne","avatar_url":"https://avatars.githubusercontent.com/u/104161?"},"repo":{"id":210067143,"name":"mirisuzanne/teacup","url":"https://api.github.com/repos/mirisuzanne/teacup"},"payload":{"action":"closed","number":1,"pull_request":{"url":"https://api.github.com/repos/mirisuzanne/teacup/pulls/1","id":325139522,"node_id":"MDExOlB1bGxSZXF1ZXN0MzI1MTM5NTIy","html_url":"https://github.com/mirisuzanne/teacup/pull/1","diff_url":"https://github.com/mirisuzanne/teacup/pull/1.diff","patch_url":"https://github.com/mirisuzanne/teacup/pull/1.patch","issue_url":"https://api.github.com/repos/mirisuzanne/teacup/issues/1","number":1,"state":"closed","locked":false,"title":"Use CSS from node module","user":{"login":"mirisuzanne","id":104161,"node_id":"MDQ6VXNlcjEwNDE2MQ==","avatar_url":"https://avatars2.githubusercontent.com/u/104161?v=4","gravatar_id":"","url":"https://api.github.com/users/mirisuzanne","html_url":"https://github.com/mirisuzanne","followers_url":"https://api.github.com/users/mirisuzanne/followers","following_url":"https://api.github.com/users/mirisuzanne/following{/other_user}","gists_url":"https://api.github.com/users/mirisuzanne/gists{/gist_id}","starred_url":"https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mirisuzanne/subscriptions","organizations_url":"https://api.github.com/users/mirisuzanne/orgs","repos_url":"https://api.github.com/users/mirisuzanne/repos","events_url":"https://api.github.com/users/mirisuzanne/events{/privacy}","received_events_url":"https://api.github.com/users/mirisuzanne/received_events","type":"User","site_admin":false},"body":null,"created_at":"2019-10-07T05:56:10Z","updated_at":"2019-12-05T08:22:33Z","closed_at":"2019-12-05T08:22:33Z","merged_at":"2019-12-05T08:22:33Z","merge_commit_sha":"686ad159d32220b6a57d39b1d0186d0661f1824f","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"https://api.github.com/repos/mirisuzanne/teacup/pulls/1/commits","review_comments_url":"https://api.github.com/repos/mirisuzanne/teacup/pulls/1/comments","review_comment_url":"https://api.github.com/repos/mirisuzanne/teacup/pulls/comments{/number}","comments_url":"https://api.github.com/repos/mirisuzanne/teacup/issues/1/comments","statuses_url":"https://api.github.com/repos/mirisuzanne/teacup/statuses/a9f2304f0d3eb1b0456feda4950e278db17397cb","head":{"label":"mirisuzanne:ccs-module","ref":"ccs-module","sha":"a9f2304f0d3eb1b0456feda4950e278db17397cb","user":{"login":"mirisuzanne","id":104161,"node_id":"MDQ6VXNlcjEwNDE2MQ==","avatar_url":"https://avatars2.githubusercontent.com/u/104161?v=4","gravatar_id":"","url":"https://api.github.com/users/mirisuzanne","html_url":"https://github.com/mirisuzanne","followers_url":"https://api.github.com/users/mirisuzanne/followers","following_url":"https://api.github.com/users/mirisuzanne/following{/other_user}","gists_url":"https://api.github.com/users/mirisuzanne/gists{/gist_id}","starred_url":"https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mirisuzanne/subscriptions","organizations_url":"https://api.github.com/users/mirisuzanne/orgs","repos_url":"https://api.github.com/users/mirisuzanne/repos","events_url":"https://api.github.com/users/mirisuzanne/events{/privacy}","received_events_url":"https://api.github.com/users/mirisuzanne/received_events","type":"User","site_admin":false},"repo":{"id":210067143,"node_id":"MDEwOlJlcG9zaXRvcnkyMTAwNjcxNDM=","name":"teacup","full_name":"mirisuzanne/teacup","private":false,"owner":{"login":"mirisuzanne","id":104161,"node_id":"MDQ6VXNlcjEwNDE2MQ==","avatar_url":"https://avatars2.githubusercontent.com/u/104161?v=4","gravatar_id":"","url":"https://api.github.com/users/mirisuza ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11017412629',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 104161,
#    'login': 'mirisuzanne',
#    'display_login': 'mirisuzanne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mirisuzanne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104161?'},
#   'repo': {'id': 210067143,
#    'name': 'mirisuzanne/teacup',
#    'url': 'https://api.github.com/repos/mirisuzanne/teacup'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1',
#     'id': 325139522,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzI1MTM5NTIy',
#     'html_url': 'https://github.com/mirisuzanne/teacup/pull/1',
#     'diff_url': 'https://github.com/mirisuzanne/teacup/pull/1.diff',
#     'patch_url': 'https://github.com/mirisuzanne/teacup/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/1',
#     'number': 1,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Use CSS from node module',
#     'user': {'login': 'mirisuzanne',
#      'id': 104161,
#      'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mirisuzanne',
#      'html_url': 'https://github.com/mirisuzanne',
#      'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#      'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#      'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#      'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2019-10-07T05:56:10Z',
#     'updated_at': '2019-12-05T08:22:33Z',
#     'closed_at': '2019-12-05T08:22:33Z',
#     'merged_at': '2019-12-05T08:22:33Z',
#     'merge_commit_sha': '686ad159d32220b6a57d39b1d0186d0661f1824f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/mirisuzanne/teacup/statuses/a9f2304f0d3eb1b0456feda4950e278db17397cb',
#     'head': {'label': 'mirisuzanne:ccs-module',
#      'ref': 'ccs-module',
#      'sha': 'a9f2304f0d3eb1b0456feda4950e278db17397cb',
#      'user': {'login': 'mirisuzanne',
#       'id': 104161,
#       'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mirisuzanne',
#       'html_url': 'https://github.com/mirisuzanne',
#       'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#       'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#       'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#       'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 210067143,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTAwNjcxNDM=',
#       'name': 'teacup',
#       'full_name': 'mirisuzanne/teacup',
#       'private': False,
#       'owner': {'login': 'mirisuzanne',
#        'id': 104161,
#        'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mirisuzanne',
#        'html_url': 'https://github.com/mirisuzanne',
#        'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#        'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#        'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#        'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mirisuzanne/teacup',
#       'description': 'the new new teacup gorilla',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mirisuzanne/teacup',
#       'forks_url': 'https://api.github.com/repos/mirisuzanne/teacup/forks',
#       'keys_url': 'https://api.github.com/repos/mirisuzanne/teacup/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mirisuzanne/teacup/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mirisuzanne/teacup/teams',
#       'hooks_url': 'https://api.github.com/repos/mirisuzanne/teacup/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mirisuzanne/teacup/events',
#       'assignees_url': 'https://api.github.com/repos/mirisuzanne/teacup/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mirisuzanne/teacup/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mirisuzanne/teacup/tags',
#       'blobs_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mirisuzanne/teacup/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mirisuzanne/teacup/languages',
#       'stargazers_url': 'https://api.github.com/repos/mirisuzanne/teacup/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mirisuzanne/teacup/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mirisuzanne/teacup/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mirisuzanne/teacup/subscription',
#       'commits_url': 'https://api.github.com/repos/mirisuzanne/teacup/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mirisuzanne/teacup/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mirisuzanne/teacup/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mirisuzanne/teacup/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mirisuzanne/teacup/merges',
#       'archive_url': 'https://api.github.com/repos/mirisuzanne/teacup/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mirisuzanne/teacup/downloads',
#       'issues_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mirisuzanne/teacup/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mirisuzanne/teacup/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mirisuzanne/teacup/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mirisuzanne/teacup/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mirisuzanne/teacup/deployments',
#       'created_at': '2019-09-21T23:53:56Z',
#       'updated_at': '2019-10-10T11:50:08Z',
#       'pushed_at': '2019-12-05T08:22:33Z',
#       'git_url': 'git://github.com/mirisuzanne/teacup.git',
#       'ssh_url': 'git@github.com:mirisuzanne/teacup.git',
#       'clone_url': 'https://github.com/mirisuzanne/teacup.git',
#       'svn_url': 'https://github.com/mirisuzanne/teacup',
#       'homepage': None,
#       'size': 163906,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'mirisuzanne:master',
#      'ref': 'master',
#      'sha': '29af67b7f5617a8915886a3d7be49999614e556f',
#      'user': {'login': 'mirisuzanne',
#       'id': 104161,
#       'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mirisuzanne',
#       'html_url': 'https://github.com/mirisuzanne',
#       'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#       'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#       'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#       'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 210067143,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTAwNjcxNDM=',
#       'name': 'teacup',
#       'full_name': 'mirisuzanne/teacup',
#       'private': False,
#       'owner': {'login': 'mirisuzanne',
#        'id': 104161,
#        'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mirisuzanne',
#        'html_url': 'https://github.com/mirisuzanne',
#        'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#        'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#        'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#        'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mirisuzanne/teacup',
#       'description': 'the new new teacup gorilla',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mirisuzanne/teacup',
#       'forks_url': 'https://api.github.com/repos/mirisuzanne/teacup/forks',
#       'keys_url': 'https://api.github.com/repos/mirisuzanne/teacup/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mirisuzanne/teacup/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mirisuzanne/teacup/teams',
#       'hooks_url': 'https://api.github.com/repos/mirisuzanne/teacup/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mirisuzanne/teacup/events',
#       'assignees_url': 'https://api.github.com/repos/mirisuzanne/teacup/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mirisuzanne/teacup/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mirisuzanne/teacup/tags',
#       'blobs_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mirisuzanne/teacup/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mirisuzanne/teacup/languages',
#       'stargazers_url': 'https://api.github.com/repos/mirisuzanne/teacup/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mirisuzanne/teacup/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mirisuzanne/teacup/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mirisuzanne/teacup/subscription',
#       'commits_url': 'https://api.github.com/repos/mirisuzanne/teacup/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mirisuzanne/teacup/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mirisuzanne/teacup/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mirisuzanne/teacup/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mirisuzanne/teacup/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mirisuzanne/teacup/merges',
#       'archive_url': 'https://api.github.com/repos/mirisuzanne/teacup/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mirisuzanne/teacup/downloads',
#       'issues_url': 'https://api.github.com/repos/mirisuzanne/teacup/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mirisuzanne/teacup/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mirisuzanne/teacup/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mirisuzanne/teacup/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mirisuzanne/teacup/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mirisuzanne/teacup/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mirisuzanne/teacup/deployments',
#       'created_at': '2019-09-21T23:53:56Z',
#       'updated_at': '2019-10-10T11:50:08Z',
#       'pushed_at': '2019-12-05T08:22:33Z',
#       'git_url': 'git://github.com/mirisuzanne/teacup.git',
#       'ssh_url': 'git@github.com:mirisuzanne/teacup.git',
#       'clone_url': 'https://github.com/mirisuzanne/teacup.git',
#       'svn_url': 'https://github.com/mirisuzanne/teacup',
#       'homepage': None,
#       'size': 163906,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1'},
#      'html': {'href': 'https://github.com/mirisuzanne/teacup/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mirisuzanne/teacup/statuses/a9f2304f0d3eb1b0456feda4950e278db17397cb'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'mirisuzanne',
#      'id': 104161,
#      'node_id': 'MDQ6VXNlcjEwNDE2MQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/104161?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mirisuzanne',
#      'html_url': 'https://github.com/mirisuzanne',
#      'followers_url': 'https://api.github.com/users/mirisuzanne/followers',
#      'following_url': 'https://api.github.com/users/mirisuzanne/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mirisuzanne/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mirisuzanne/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mirisuzanne/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mirisuzanne/orgs',
#      'repos_url': 'https://api.github.com/users/mirisuzanne/repos',
#      'events_url': 'https://api.github.com/users/mirisuzanne/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mirisuzanne/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 6,
#     'additions': 3649,
#     'deletions': 5914,
#     'changed_files': 410}},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412620',
#   'type': 'PushEvent',
#   'actor': {'id': 38442554,
#    'login': 'EdinK1',
#    'display_login': 'EdinK1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EdinK1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38442554?'},
#   'repo': {'id': 226047858,
#    'name': 'EdinK1/mini-trello',
#    'url': 'https://api.github.com/repos/EdinK1/mini-trello'},
#   'payload': {'push_id': 4358272050,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '976a63af87f3a31e42fc91257188e1c51162d1c5',
#    'before': 'bbc51f35295266bb06bfe97ec06cbcd87e998aab',
#    'commits': [{'sha': '976a63af87f3a31e42fc91257188e1c51162d1c5',
#      'author': {'email': 'edinkaymakchi@gmail.com', 'name': 'EdinK1'},
#      'message': 'add license with mklicense made by @shwilliam <3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EdinK1/mini-trello/commits/976a63af87f3a31e42fc91257188e1c51162d1c5'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412606',
#   'type': 'PushEvent',
#   'actor': {'id': 23522177,
#    'login': 'svengrav',
#    'display_login': 'svengrav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svengrav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23522177?'},
#   'repo': {'id': 219723252,
#    'name': 'svengrav/navcontainerhelper',
#    'url': 'https://api.github.com/repos/svengrav/navcontainerhelper'},
#   'payload': {'push_id': 4358272037,
#    'size': 71,
#    'distinct_size': 71,
#    'ref': 'refs/heads/master',
#    'head': '8c41e249e05d17db25b4189277f8169899bd92e2',
#    'before': '408ebeaab599f44c27d8169f60df3e19ad772800',
#    'commits': [{'sha': '51d8f53849b6331c021e5e8a979e6f991a5c786f',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Allow donotexport if not usebaseline',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/51d8f53849b6331c021e5e8a979e6f991a5c786f'},
#     {'sha': 'c945fff2117d55f1e79e0299656823938117538d',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #720 from microsoft/dev\n\nAllow donotexport if not usebaseline',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/c945fff2117d55f1e79e0299656823938117538d'},
#     {'sha': 'b374bfdb495334fcfce4710027f9487e4570a526',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #715 from svengrav/master\n\nAdded Join-Path instead of "+" to prevent broken paths',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/b374bfdb495334fcfce4710027f9487e4570a526'},
#     {'sha': '4da61b948efcab10da2cc2f50c9e6709daff1d48',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'PR 715 rel notes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/4da61b948efcab10da2cc2f50c9e6709daff1d48'},
#     {'sha': 'cf46c61a00917c595518df8855a8608c85a7b93d',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #721 from microsoft/dev\n\nPR 715 rel notes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/cf46c61a00917c595518df8855a8608c85a7b93d'},
#     {'sha': '539c32ae0b248bbcc123428596617eca42cca19c',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #722 from microsoft/master\n\nback',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/539c32ae0b248bbcc123428596617eca42cca19c'},
#     {'sha': 'd184d3dcfd117728790500cdca0d324e22eadb85',
#      'author': {'email': 'gunnar@navision.guru',
#       'name': 'Gunnar Thor Gestsson'},
#      'message': 'Add CopyAppToSymbols to Compile-App\n\nUseful functionality when repository has multiple apps',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/d184d3dcfd117728790500cdca0d324e22eadb85'},
#     {'sha': '236ae5619658647ab19a609d584d85af98aba0c1',
#      'author': {'email': 'gunnar@navision.guru',
#       'name': 'Gunnar Thor Gestsson'},
#      'message': 'Parameter renamed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/236ae5619658647ab19a609d584d85af98aba0c1'},
#     {'sha': '808af00c4b49a7a43b379dfe0548e7d95122ceb8',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #726 from gunnargestsson/Add_CopyAppToSymbols_To_Compile\n\nAdd CopyAppToSymbols to Compile-App',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/808af00c4b49a7a43b379dfe0548e7d95122ceb8'},
#     {'sha': '890c96c77157dcb0f3b49794976856b3bc9222a0',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Issue #728',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/890c96c77157dcb0f3b49794976856b3bc9222a0'},
#     {'sha': '9d5f595fbf4ea916be3bd9c36d6b80dc78477599',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'update releasenotes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/9d5f595fbf4ea916be3bd9c36d6b80dc78477599'},
#     {'sha': '1184d35f5e2f9616481d98237a45b84aa19f417b',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Issue #729',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/1184d35f5e2f9616481d98237a45b84aa19f417b'},
#     {'sha': 'd3562cb2a3c57dd68b6d59c5b294248f8e665149',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Issue #716',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/d3562cb2a3c57dd68b6d59c5b294248f8e665149'},
#     {'sha': '65153c253c93efe802b3e9a1f75425f0192c9930',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Issue #666',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/65153c253c93efe802b3e9a1f75425f0192c9930'},
#     {'sha': '51002e43a2460094d493f0cbfac9527cb35138b8',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Issue #717',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/51002e43a2460094d493f0cbfac9527cb35138b8'},
#     {'sha': 'c5562d1381dcf71005aeee42ea80cb08f62921d8',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #730 from microsoft/dev\n\nIssues',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/c5562d1381dcf71005aeee42ea80cb08f62921d8'},
#     {'sha': '17ffb2635add8cd2b80ca154ee4dab082be69f3c',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Add parameter DestinationDatabase to new tenant',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/17ffb2635add8cd2b80ca154ee4dab082be69f3c'},
#     {'sha': 'f1c6cfd0655606845feaec95b2968ce48f564006',
#      'author': {'email': 'freddyk@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'add parameter databasename to remove tenant',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/f1c6cfd0655606845feaec95b2968ce48f564006'},
#     {'sha': 'd1558881f0cd0278400d3e4c678a22f97967c12d',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #731 from microsoft/dev\n\nTenant database name',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/d1558881f0cd0278400d3e4c678a22f97967c12d'},
#     {'sha': 'b97493ce81afd1bd172aa9bf99ff0fad145265ed',
#      'author': {'email': 'freddy.kristiansen@microsoft.com',
#       'name': 'Freddy Kristiansen'},
#      'message': 'Merge pull request #732 from microsoft/master\n\nreverse',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/svengrav/navcontainerhelper/commits/b97493ce81afd1bd172aa9bf99ff0fad145265ed'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412595',
#   'type': 'IssuesEvent',
#   'actor': {'id': 3870410,
#    'login': 'afontenot',
#    'display_login': 'afontenot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/afontenot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3870410?'},
#   'repo': {'id': 55899285,
#    'name': 'WyohKnott/image-formats-comparison',
#    'url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison/issues/10',
#     'repository_url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison',
#     'labels_url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison/issues/10/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison/issues/10/comments',
#     'events_url': 'https://api.github.com/repos/WyohKnott/image-formats-comparison/issues/10/events',
#     'html_url': 'https://github.com/WyohKnott/image-formats-comparison/issues/10',
#     'id': 533195691,
#     'node_id': 'MDU6SXNzdWU1MzMxOTU2OTE=',
#     'number': 10,
#     'title': 'Misleading resampling',
#     'user': {'login': 'afontenot',
#      'id': 3870410,
#      'node_id': 'MDQ6VXNlcjM4NzA0MTA=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/3870410?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/afontenot',
#      'html_url': 'https://github.com/afontenot',
#      'followers_url': 'https://api.github.com/users/afontenot/followers',
#      'following_url': 'https://api.github.com/users/afontenot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/afontenot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/afontenot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/afontenot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/afontenot/orgs',
#      'repos_url': 'https://api.github.com/users/afontenot/repos',
#      'events_url': 'https://api.github.com/users/afontenot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/afontenot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-05T08:22:32Z',
#     'updated_at': '2019-12-05T08:22:32Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "Hi, this is related to #4 but not the same issue. \r\n\r\nThe issue is that some formats like BPG (the ones rendered by Javascript?) are getting resampled with Lanczos2 before they're rendered into a PNG for the browser, and other formats are not getting resampled at all (or at least are resampled very badly) - including the original image! This leads to some absurd results where parts of an image look better on BPG small than they do in the original, and makes other comparisons difficult.\r\n\r\nA good example of this is Seikima-II, which shows a large number of red and blue subsampling artifacts in the original. The visual quality of the arm in the picture is actually better in BPG small due to getting resampled: https://wyohknott.github.io/image-formats-comparison/#seikima-ii&bpg=s&png=l\r\n\r\nThe solution to this is pretty simple; either don't resample any of the images before displaying them, or resample all of them the same way. \r\n\r\nTested in Firefox 71.0 and Chromium 78."}},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412579',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6545392,
#    'login': 'SkittishSloth',
#    'display_login': 'SkittishSloth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SkittishSloth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6545392?'},
#   'repo': {'id': 54388526,
#    'name': 'Kotlin/KEEP',
#    'url': 'https://api.github.com/repos/Kotlin/KEEP'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Kotlin/KEEP/issues/87',
#     'repository_url': 'https://api.github.com/repos/Kotlin/KEEP',
#     'labels_url': 'https://api.github.com/repos/Kotlin/KEEP/issues/87/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Kotlin/KEEP/issues/87/comments',
#     'events_url': 'https://api.github.com/repos/Kotlin/KEEP/issues/87/events',
#     'html_url': 'https://github.com/Kotlin/KEEP/pull/87',
#     'id': 262200015,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MTQ0MjY0MTkx',
#     'number': 87,
#     'title': 'Compile-time Extension Interfaces',
#     'user': {'login': 'raulraja',
#      'id': 456796,
#      'node_id': 'MDQ6VXNlcjQ1Njc5Ng==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/456796?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/raulraja',
#      'html_url': 'https://github.com/raulraja',
#      'followers_url': 'https://api.github.com/users/raulraja/followers',
#      'following_url': 'https://api.github.com/users/raulraja/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/raulraja/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/raulraja/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/raulraja/subscriptions',
#      'organizations_url': 'https://api.github.com/users/raulraja/orgs',
#      'repos_url': 'https://api.github.com/users/raulraja/repos',
#      'events_url': 'https://api.github.com/users/raulraja/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/raulraja/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 304,
#     'created_at': '2017-10-02T19:31:38Z',
#     'updated_at': '2019-12-05T08:22:33Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/Kotlin/KEEP/pulls/87',
#      'html_url': 'https://github.com/Kotlin/KEEP/pull/87',
#      'diff_url': 'https://github.com/Kotlin/KEEP/pull/87.diff',
#      'patch_url': 'https://github.com/Kotlin/KEEP/pull/87.patch'},
#     'body': '## Proposal\r\n\r\nThe goal of this proposal is to enable compile-time dependency resolution through extension syntax. Overall, we want to enable "contract" interfaces to be declared as program constraints in function or class constructor arguments and enable the compiler to automatically resolve and inject those instances that must be provided with evidence in one of a given set of scopes. The resolution scopes to look for those evidences are predefined and ordered, [more details inside the proposal](https://github.com/Kotlin/KEEP/pull/87/files). \r\n\r\nIn the case of not having evidence of a required interface (program constraints), the compiler would fail and provide the proper error messages both by IntellIJ IDEA inspections and compile-time errors.\r\n\r\nThis would bring first-class named extension families to Kotlin. Extension families allow us to guarantee that a given data type (class, interface, etc.) satisfies behaviors (a group of functions or properties) that are decoupled from the type\'s inheritance hierarchy. \r\n\r\nUnlike the traditional subtype style composition where users are forced to extend and implement classes and interfaces, extension families favor horizontal composition based on compile-time resolution between types and their extensions.\r\n\r\n## Current code status\r\n\r\nThanks to @truizlop and @jorgecastilloprz,[we already have a working POC](https://github.com/arrow-kt/kotlin/pull/6) where we\'ve coded a big part of the KEEP-87. There are still some additional behaviors we\'d need to code that have been clarified on the KEEP though, and we\'d love to get JetBrains help on iterating those. Instructions about how to test it have been provided within the ["How to try?"](https://github.com/Kotlin/KEEP/pull/87/files#diff-71ce63753e7dbd24fcb8b631141583ccR431) section of the keep, where we have also provided a code sample.\r\n\r\n## Rewording\r\n\r\nWe have revamped the initial proposal given Type Classes are not really our aim here, but compile-time dependency resolution for Kotlin. The nature of the proposal has not changed a lot, just suffered a major refactor so it\'s more in the line of what a generic language feature like this one would be, and also to fit the compiler implementation feedback we\'ve got from some JetBrains devs these later months. \r\n\r\nWe believe the compiler could support compile-time dependency resolution out of the box, as other modern laguages already do. We believe some infrastructure patterns would fit better as built-in language features, so users can get their canonical solution for that already provided and focus their work on the actual domain requirements and business logics of their programs. We\'ve seen similar things in other languages that provide built in support for concurrency and other stuff.\r\n\r\n## How to contribute\r\n\r\nWant to help to bring compile time extension resolution to Kotlin?. A fork is being provisioned where a reference implementation based on this proposal will take place at https://github.com/arrow-kt/kotlin'},
#    'comment': {'url': 'https://api.github.com/repos/Kotlin/KEEP/issues/comments/562022768',
#     'html_url': 'https://github.com/Kotlin/KEEP/pull/87#issuecomment-562022768',
#     'issue_url': 'https://api.github.com/repos/Kotlin/KEEP/issues/87',
#     'id': 562022768,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjAyMjc2OA==',
#     'user': {'login': 'SkittishSloth',
#      'id': 6545392,
#      'node_id': 'MDQ6VXNlcjY1NDUzOTI=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6545392?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/SkittishSloth',
#      'html_url': 'https://github.com/SkittishSloth',
#      'followers_url': 'https://api.github.com/users/SkittishSloth/followers',
#      'following_url': 'https://api.github.com/users/SkittishSloth/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/SkittishSloth/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/SkittishSloth/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/SkittishSloth/subscriptions',
#      'organizations_url': 'https://api.github.com/users/SkittishSloth/orgs',
#      'repos_url': 'https://api.github.com/users/SkittishSloth/repos',
#      'events_url': 'https://api.github.com/users/SkittishSloth/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/SkittishSloth/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-05T08:22:33Z',
#     'updated_at': '2019-12-05T08:22:33Z',
#     'author_association': 'NONE',
#     'body': "I'm not sure I follow, but I want to - can you elaborate a bit more? I think I'm kinda stuck somewhere in type vs class land or something along those lines and that's where my confusion comes from."}},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z',
#   'org': {'id': 1446536,
#    'login': 'Kotlin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Kotlin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1446536?'}},
#  {'id': '11017412570',
#   'type': 'DeleteEvent',
#   'actor': {'id': 19278921,
#    'login': 'demetoir',
#    'display_login': 'demetoir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/demetoir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19278921?'},
#   'repo': {'id': 219638215,
#    'name': 'demetoir/2019-21',
#    'url': 'https://api.github.com/repos/demetoir/2019-21'},
#   'payload': {'ref': 'deply/oauth',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412556',
#   'type': 'ForkEvent',
#   'actor': {'id': 5197171,
#    'login': 'anden-dev',
#    'display_login': 'anden-dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anden-dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5197171?'},
#   'repo': {'id': 106334570,
#    'name': '7Factor/terraform-aws-concourse',
#    'url': 'https://api.github.com/repos/7Factor/terraform-aws-concourse'},
#   'payload': {'forkee': {'id': 226051706,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYwNTE3MDY=',
#     'name': 'terraform-aws-concourse',
#     'full_name': 'anden-dev/terraform-aws-concourse',
#     'private': False,
#     'owner': {'login': 'anden-dev',
#      'id': 5197171,
#      'node_id': 'MDQ6VXNlcjUxOTcxNzE=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/5197171?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/anden-dev',
#      'html_url': 'https://github.com/anden-dev',
#      'followers_url': 'https://api.github.com/users/anden-dev/followers',
#      'following_url': 'https://api.github.com/users/anden-dev/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/anden-dev/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/anden-dev/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/anden-dev/subscriptions',
#      'organizations_url': 'https://api.github.com/users/anden-dev/orgs',
#      'repos_url': 'https://api.github.com/users/anden-dev/repos',
#      'events_url': 'https://api.github.com/users/anden-dev/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/anden-dev/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/anden-dev/terraform-aws-concourse',
#     'description': 'Terraform Module for a distributed concourse cluster on AWS',
#     'fork': True,
#     'url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse',
#     'forks_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/forks',
#     'keys_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/teams',
#     'hooks_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/hooks',
#     'issue_events_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/events',
#     'assignees_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/tags',
#     'blobs_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/languages',
#     'stargazers_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/stargazers',
#     'contributors_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/contributors',
#     'subscribers_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/subscribers',
#     'subscription_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/subscription',
#     'commits_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/merges',
#     'archive_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/downloads',
#     'issues_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/anden-dev/terraform-aws-concourse/deployments',
#     'created_at': '2019-12-05T08:22:32Z',
#     'updated_at': '2019-10-10T20:07:30Z',
#     'pushed_at': '2019-10-10T20:07:28Z',
#     'git_url': 'git://github.com/anden-dev/terraform-aws-concourse.git',
#     'ssh_url': 'git@github.com:anden-dev/terraform-aws-concourse.git',
#     'clone_url': 'https://github.com/anden-dev/terraform-aws-concourse.git',
#     'svn_url': 'https://github.com/anden-dev/terraform-aws-concourse',
#     'homepage': '',
#     'size': 233,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z',
#   'org': {'id': 19713528,
#    'login': '7Factor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/7Factor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19713528?'}},
#  {'id': '11017412551',
#   'type': 'PushEvent',
#   'actor': {'id': 48369705,
#    'login': 'mister-ard97',
#    'display_login': 'mister-ard97',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mister-ard97',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48369705?'},
#   'repo': {'id': 221181671,
#    'name': 'mister-ard97/ng3l3sc0',
#    'url': 'https://api.github.com/repos/mister-ard97/ng3l3sc0'},
#   'payload': {'push_id': 4358272017,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/reza',
#    'head': '4d6053437bed6e851e02993485df10da35cf8f2b',
#    'before': '22e0c5f93ec4ff69f6d999d4cd7287c473e17689',
#    'commits': [{'sha': '4d6053437bed6e851e02993485df10da35cf8f2b',
#      'author': {'email': 'rezardiansyah1997@gmail.com',
#       'name': 'mister-ard97'},
#      'message': 'commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mister-ard97/ng3l3sc0/commits/4d6053437bed6e851e02993485df10da35cf8f2b'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:33Z'},
#  {'id': '11017412534',
#   'type': 'PushEvent',
#   'actor': {'id': 38294863,
#    'login': 'samyabouseda',
#    'display_login': 'samyabouseda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/samyabouseda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38294863?'},
#   'repo': {'id': 225907509,
#    'name': 'samyabouseda/ishop4less-product-service',
#    'url': 'https://api.github.com/repos/samyabouseda/ishop4less-product-service'},
#   'payload': {'push_id': 4358272009,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/production',
#    'head': '41bbddda92e446018e3ddb530f5956950bef60f3',
#    'before': 'cc89ed9028beab96231524db35ba3060234f8ad8',
# ...
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'inveniosoftware:master',
#      'ref': 'master',
#      'sha': 'ea6cd9c3a2d74622ec245f6bce94c27ab0a97227',
#      'user': {'login': 'inveniosoftware',
#       'id': 1157480,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNTc0ODA=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/1157480?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/inveniosoftware',
#       'html_url': 'https://github.com/inveniosoftware',
#       'followers_url': 'https://api.github.com/users/inveniosoftware/followers',
#       'following_url': 'https://api.github.com/users/inveniosoftware/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/inveniosoftware/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/inveniosoftware/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/inveniosoftware/subscriptions',
#       'organizations_url': 'https://api.github.com/users/inveniosoftware/orgs',
#       'repos_url': 'https://api.github.com/users/inveniosoftware/repos',
#       'events_url': 'https://api.github.com/users/inveniosoftware/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/inveniosoftware/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 188058383,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODgwNTgzODM=',
#       'name': 'invenio-app-rdm',
#       'full_name': 'inveniosoftware/invenio-app-rdm',
#       'private': False,
#       'owner': {'login': 'inveniosoftware',
#        'id': 1157480,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNTc0ODA=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/1157480?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/inveniosoftware',
#        'html_url': 'https://github.com/inveniosoftware',
#        'followers_url': 'https://api.github.com/users/inveniosoftware/followers',
#        'following_url': 'https://api.github.com/users/inveniosoftware/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/inveniosoftware/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/inveniosoftware/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/inveniosoftware/subscriptions',
#        'organizations_url': 'https://api.github.com/users/inveniosoftware/orgs',
#        'repos_url': 'https://api.github.com/users/inveniosoftware/repos',
#        'events_url': 'https://api.github.com/users/inveniosoftware/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/inveniosoftware/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/inveniosoftware/invenio-app-rdm',
#       'description': 'RDM flavour of Invenio',
#       'fork': False,
#       'url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm',
#       'forks_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/forks',
#       'keys_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/teams',
#       'hooks_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/hooks',
#       'issue_events_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/events',
#       'assignees_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/tags',
#       'blobs_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/languages',
#       'stargazers_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/stargazers',
#       'contributors_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/contributors',
#       'subscribers_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/subscribers',
#       'subscription_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/subscription',
#       'commits_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/merges',
#       'archive_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/downloads',
#       'issues_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/deployments',
#       'created_at': '2019-05-22T14:45:04Z',
#       'updated_at': '2019-11-27T13:41:01Z',
#       'pushed_at': '2019-12-04T23:11:20Z',
#       'git_url': 'git://github.com/inveniosoftware/invenio-app-rdm.git',
#       'ssh_url': 'git@github.com:inveniosoftware/invenio-app-rdm.git',
#       'clone_url': 'https://github.com/inveniosoftware/invenio-app-rdm.git',
#       'svn_url': 'https://github.com/inveniosoftware/invenio-app-rdm',
#       'homepage': 'https://invenio-app-rdm.readthedocs.io',
#       'size': 106,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 3,
#       'open_issues': 16,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/pulls/34'},
#      'html': {'href': 'https://github.com/inveniosoftware/invenio-app-rdm/pull/34'},
#      'issue': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/issues/34'},
#      'comments': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/issues/34/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/pulls/34/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/pulls/34/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/inveniosoftware/invenio-app-rdm/statuses/859db77db107a010c6631b7ea11a7dd54bb6e8e3'}},
#     'author_association': 'CONTRIBUTOR'}},
#   'public': True,
#   'created_at': '2019-12-05T08:19:14Z',
#   'org': {'id': 1157480,
#    'login': 'inveniosoftware',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/inveniosoftware',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1157480?'}},
#  {'id': '11017412475',
#   'type': 'CreateEvent',
#   'actor': {'id': 58548148,
#    'login': 'ciapciak',
#    'display_login': 'ciapciak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ciapciak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58548148?'},
#   'repo': {'id': 226051703,
#    'name': 'ciapciak/iot-store',
#    'url': 'https://api.github.com/repos/ciapciak/iot-store'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z'},
#  {'id': '11017412472',
#   'type': 'PushEvent',
#   'actor': {'id': 37640382,
#    'login': 'Patryk728',
#    'display_login': 'Patryk728',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Patryk728',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37640382?'},
#   'repo': {'id': 226049174,
#    'name': 'Patryk728/Test',
#    'url': 'https://api.github.com/repos/Patryk728/Test'},
#   'payload': {'push_id': 4358271976,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8f7bc7c661a1e8f37723c4c177617412cc2bfb14',
#    'before': '26246b4956cea27d17990446060e3cd3973eac70',
#    'commits': [{'sha': '8f7bc7c661a1e8f37723c4c177617412cc2bfb14',
#      'author': {'email': 'patryk.studia2017@gmail.com', 'name': 'Patryk728'},
#      'message': "Wyczyszczenie przed rebase'em",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Patryk728/Test/commits/8f7bc7c661a1e8f37723c4c177617412cc2bfb14'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z'},
#  {'id': '11017412467',
#   'type': 'CreateEvent',
#   'actor': {'id': 47417122,
#    'login': 'Yes-IT',
#    'display_login': 'Yes-IT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Yes-IT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47417122?'},
#   'repo': {'id': 226051704,
#    'name': 'Yes-IT/bollyx',
#    'url': 'https://api.github.com/repos/Yes-IT/bollyx'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z'},
#  {'id': '11017412461',
#   'type': 'PushEvent',
#   'actor': {'id': 55864761,
#    'login': 'Maria-Yamaguchi',
#    'display_login': 'Maria-Yamaguchi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Maria-Yamaguchi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55864761?'},
#   'repo': {'id': 220365907,
#    'name': 'Infosys-ProjectA-2019/proa2019-project2-5101_b',
#    'url': 'https://api.github.com/repos/Infosys-ProjectA-2019/proa2019-project2-5101_b'},
#   'payload': {'push_id': 4358271971,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'eaeca9315b7d42aa9bbcf90e9c7f15cb44f0595c',
#    'before': '2451c1e77a2a3e8499851047a41b6bf4dca71b14',
#    'commits': [{'sha': 'eaeca9315b7d42aa9bbcf90e9c7f15cb44f0595c',
#      'author': {'email': '55864761+Maria-Yamaguchi@users.noreply.github.com',
#       'name': 'Maria-Yamaguchi'},
#      'message': '変更',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Infosys-ProjectA-2019/proa2019-project2-5101_b/commits/eaeca9315b7d42aa9bbcf90e9c7f15cb44f0595c'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z',
#   'org': {'id': 55615281,
#    'login': 'Infosys-ProjectA-2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Infosys-ProjectA-2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55615281?'}},
#  {'id': '11017412458',
#   'type': 'PushEvent',
#   'actor': {'id': 49858855,
#    'login': 'eps88',
#    'display_login': 'eps88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eps88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49858855?'},
#   'repo': {'id': 225562345,
#    'name': 'eps88/icon-btp-0.5-PoC',
#    'url': 'https://api.github.com/repos/eps88/icon-btp-0.5-PoC'},
#   'payload': {'push_id': 4358271969,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '65b88f5882f349017b67cf27f92aba6fc0e5107f',
#    'before': '6dc56d5fe75061107c9c6f32ddb1c0f55aad2125',
#    'commits': [{'sha': '65b88f5882f349017b67cf27f92aba6fc0e5107f',
#      'author': {'email': 'dongchang.yoo@icon.foudation', 'name': 'dongchang'},
#      'message': 'README ver3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eps88/icon-btp-0.5-PoC/commits/65b88f5882f349017b67cf27f92aba6fc0e5107f'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z'},
#  {'id': '11017412454',
#   'type': 'CreateEvent',
#   'actor': {'id': 55005374,
#    'login': 'Lunox-Code',
#    'display_login': 'Lunox-Code',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lunox-Code',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55005374?'},
#   'repo': {'id': 226051701,
#    'name': 'Lunox-Code/Mini-Picasso',
#    'url': 'https://api.github.com/repos/Lunox-Code/Mini-Picasso'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Showing images from URL using Picasso',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z'},
#  {'id': '11017412447',
#   'type': 'WatchEvent',
#   'actor': {'id': 9137289,
#    'login': 'GeorgeDu',
#    'display_login': 'GeorgeDu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GeorgeDu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9137289?'},
#   'repo': {'id': 110506486,
#    'name': 'cvdfoundation/open-images-dataset',
#    'url': 'https://api.github.com/repos/cvdfoundation/open-images-dataset'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-05T08:22:32Z',
#   'org': {'id': 26589718,
#    'login': 'cvdfoundation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cvdfoundation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26589718?'}},
#  {'id': '11017412427',
#   'type': 'PushEvent',
#   'actor': {'id': 31909376,
#    'login': 'wuchengji',
#    'display_login': 'wuchengji',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wuchengji',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31909376?'},
#   'repo': {'id': 225544907,
#    'name': 'wuchengji/wuchengji.github.io',
#    'url': 'https://api.github.com/repos/wuchengji/wuchengji.github.io'},
#   'payload': {'push_id': 4358271963,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7a5ec2deb353dc299e32397a2257d1ea70ffeb46',
#    'before': 'a2966b98551055b4330960c0330711a4e117fe47',
#    'commits': [{'sha': '7a5ec2deb353dc299e32397a2257d1ea70ffeb46',
#      'author': {'email': 'wuchengji@meeruu.com', 'name': 'wuchengji'},
#      'message': '2019-12-05-16:22:16',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wuchengji/wuchengji.github.io/commits/7a5ec2deb353dc299e32397a2257d1ea70ffeb46'}]},
#   'public': True,
#   'created_at': '2019-12-05T08:22:31Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')

json.loads(r.text)

# %%
import requests
import json

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')

json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2560H025',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 3.03},
#   {'StationIdentifier': '2560H022',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 194.54},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 3.01},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 4.44},
#   {'StationIdentifier': '2420H046',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 35.93},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 22.11},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 245.49},
#   {'StationIdentifier': '2370H024',
#    'RecordTime': 'Dec 5, 2019 12:00:00 AM',
#    'WaterLevel': 195.43},
#   {'StationIdentifier': '1680H004',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 1.1},
#   {'StationIdentifier': '1730H062',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 41.73},
#   {'StationIdentifier': '1740H011',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 6.61},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 140.76},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.33},
#   {'StationIdentifier': '1740H009',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 32.37},
#   {'StationIdentifier': '2420H037',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 133.39},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.49},
#   {'StationIdentifier': '1660H013',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.96},
#   {'StationIdentifier': '1730H065',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 90.68},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 5, 2019 12:20:00 AM',
#    'WaterLevel': 0.46},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1740H002',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 4.42},
#   {'StationIdentifier': '1660H011',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 1.49},
#   {'StationIdentifier': '1730H058',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 113.58},
#   {'StationIdentifier': '1650H011',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.43},
#   {'StationIdentifier': '1630H029',
#    'RecordTime': 'Dec 5, 2019 12:20:00 AM',
#    'WaterLevel': 5.02},
#   {'StationIdentifier': '2370H016',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 167.82},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 124.07},
#   {'StationIdentifier': '1730H076',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 58.07},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H045',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 5.14},
#   {'StationIdentifier': '1650H006',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 1.24},
#   {'StationIdentifier': '1630H028',
#    'RecordTime': 'Dec 5, 2019 12:20:00 AM',
#    'WaterLevel': 10.25},
#   {'StationIdentifier': '2200H028',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 277.77},
#   {'StationIdentifier': '2200H021',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 369.63},
#   {'StationIdentifier': '1730H071',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 35.33},
#   {'StationIdentifier': '1650H014',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.98},
#   {'StationIdentifier': '1730H036',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 107.43},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Dec 5, 2019 12:20:00 AM',
#    'WaterLevel': 402.48},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 69.11},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 207.6},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 25.7},
#   {'StationIdentifier': '1730H067',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1630H037',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 9.35},
#   {'StationIdentifier': '1540H031',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 10.11},
#   {'StationIdentifier': '1630H026',
#    'RecordTime': 'Dec 5, 2019 12:20:00 AM',
#    'WaterLevel': 44.49},
#   {'StationIdentifier': '1590H015',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 9.29},
#   {'StationIdentifier': '1740H007',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.75},
#   {'StationIdentifier': '1630H020',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 35.29},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 25.73},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 145.02},
#   {'StationIdentifier': '1540H014',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 7.98},
#   {'StationIdentifier': '1510H063',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 263.86},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 173.07},
#   {'StationIdentifier': '1730H079',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 548.81},
#   {'StationIdentifier': '1590H019',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 14.88},
#   {'StationIdentifier': '1550H016',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 12.28},
#   {'StationIdentifier': '1510H081',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 229.08},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 428.62},
#   {'StationIdentifier': '1510H050',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 155.53},
#   {'StationIdentifier': '1430H032',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 337.58},
#   {'StationIdentifier': '1630H013',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 15.53},
#   {'StationIdentifier': '1590H012',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 2.77},
#   {'StationIdentifier': '1550H011',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': -0.07},
#   {'StationIdentifier': '1510H057',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 88.48},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 752.4},
#   {'StationIdentifier': '1430H057',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 31.71},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 23.64},
#   {'StationIdentifier': '1580H020',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 35.42},
#   {'StationIdentifier': '1580H007',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 23.64},
#   {'StationIdentifier': '1540H038',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 54.79},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 24.98},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 4.9},
#   {'StationIdentifier': '1430H053',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 38.42},
#   {'StationIdentifier': '1430H025',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 9.96},
#   {'StationIdentifier': '1580H013',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 9.73},
#   {'StationIdentifier': '1430H038',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 75.4},
#   {'StationIdentifier': '1540H035',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 86.8},
#   {'StationIdentifier': '1430H060',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 20.1},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 264.97},
#   {'StationIdentifier': '1430H048',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 166.02},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Dec 4, 2019 5:50:00 PM',
#    'WaterLevel': 196.52},
#   {'StationIdentifier': '1550H018',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.15},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 87.53},
#   {'StationIdentifier': '1510H088',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 141.08},
#   {'StationIdentifier': '1350H019',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 33.68},
#   {'StationIdentifier': '1430H055',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 78.56},
#   {'StationIdentifier': '1430H046',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 111.07},
#   {'StationIdentifier': '1140H107',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 2.5},
#   {'StationIdentifier': '1540H036',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 247.03},
#   {'StationIdentifier': '1300H024',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 28.83},
#   {'StationIdentifier': '1140H101',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 181.93},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 471.62},
#   {'StationIdentifier': '1430H044',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 139.49},
#   {'StationIdentifier': '1510H085',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 279.8},
#   {'StationIdentifier': '1420H052',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 429.74},
#   {'StationIdentifier': '1340H010',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 0.61},
#   {'StationIdentifier': '1300H021',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': -0.86},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Dec 5, 2019 12:50:00 AM',
#    'WaterLevel': 318.71},
#   {'StationIdentifier': '1140H076',
#    'RecordTime': 'Dec 5, 2019 12:40:00 AM',
#    'WaterLevel': 135.98}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
